# %%
# %env SPDLOG_LEVEL=warning
# Out:
# env: SPDLOG_LEVEL=warning

# %%
from benchmark_utils import benchmark_with_percentiles
import matplotlib.pyplot as plt
from matplotlib.ticker import MultipleLocator
import numpy as np
import python_kernel
python_kernel.init()

# %%
N = 1024 * 1024 * 100
aHost = np.arange(N, dtype=np.float32)
bHost = np.arange(N, dtype=np.float32)

aDevice = python_kernel.create_device_buffer(aHost)
bDevice = python_kernel.create_device_buffer(bHost)
rDevice = python_kernel.create_device_buffer(aHost.size * aHost.itemsize)

# %%
workgroupSizesX = [32, 64, 128, 256, 512, 1024]

p0_values = []
p5_values = []

for size in workgroupSizesX:
    percentiles = benchmark_with_percentiles(lambda: python_kernel.add(aDevice, bDevice, rDevice, size))

    p0_values.append(percentiles[0])
    p5_values.append(percentiles[5])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 22
#      18 plt.xscale('log', base=2)
#      19 plt.xticks(workgroupSizesX, [str(x) for x in workgroupSizesX])
#      20
#      21 ax = plt.gca()
# ---> 22 ax.yaxis.set_major_locator(MultipleLocator(0.5))
#      23 ax.yaxis.set_minor_locator(MultipleLocator(0.1))
#      24
#      25 plt.xlabel('Workgroup Size X')
#
# NameError: name 'MultipleLocator' is not defined

# %%
plt.figure(figsize=(10, 6))

plt.plot(workgroupSizesX, p0_values, marker='o', label='Percentile 0')
plt.plot(workgroupSizesX, p5_values, marker='o', label='Percentile 5')

# Logarithmic X axis
plt.xscale('log', base=2)
plt.xticks(workgroupSizesX, [str(x) for x in workgroupSizesX])

ax = plt.gca()
ax.yaxis.set_major_locator(MultipleLocator(50))

plt.xlabel('Workgroup Size X')
plt.ylabel('Time, ms')
plt.title('Benchmark')
plt.grid(True, which='both', linestyle='--', alpha=0.5)
plt.legend()

plt.tight_layout()
plt.show()

# %%
python_kernel.destroy_device_buffer(aDevice)
python_kernel.destroy_device_buffer(bDevice)
python_kernel.destroy_device_buffer(rDevice)
python_kernel.clear()
